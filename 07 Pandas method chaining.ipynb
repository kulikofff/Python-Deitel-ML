# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('SampleSuperstore.csv', encoding='cp1251')
df.dropna(axis=0, inplace=True)
df.head()
# Out:
#   Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0      1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2      3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3      4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4      5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 6      7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 2     90036.0    West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0   South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0   South  OFF-ST-10000760  Office Supplies      Storage
# 6     90032.0    West  OFF-AR-10002833  Office Supplies          Art
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600       2.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775       5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680       2.0
# 6                                         Newell 322    7.2800       4.0
#
#    Discount    Profit;
# 0      0.00   41.9136;
# 2      0.00    6.8714;
# 3      0.45  -383.031;
# 4      0.20    2.5164;
# 6      0.00    1.9656;
#
# [5 rows x 21 columns]

# %%
#df overwrite
def dfbad(df):
    df_bad = df.query("Sales > 15 & Quantity == 2.0")
    df_bad['summary'] = df_bad.Sales * df_bad.Quantity
    df_bad = df_bad[['Sub-Category', 'Sales']]
    df_bad = df_bad.groupby('Sub-Category').agg(['count', 'mean'])
    df_bad = df_bad.droplevel(axis=1, level=0)
    df_bad = df_bad.query('count > 50')
    return df_bad

# %%
df_bad1 = pd.DataFrame(dfbad(df))
df_bad1
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
#               count        mean
# Sub-Category
# Accessories     157  107.520688
# Appliances       78  133.840000
# Binders         116  234.303138
# Chairs           94  323.293894
# Furnishings      85   68.275482
# Paper            98   64.563469
# Phones          194  235.043773
# Storage         114  165.037298

# %%
# %timeit dfbad(df)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# 5.54 ms ± 104 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity
# C:\Users\admin\AppData\Local\Temp\ipykernel_16204\3795367414.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bad['summary'] = df_bad.Sales * df_bad.Quantity

# %%
#Pandas Method chaining:
def dfgood(df):
    df_good = (df
        .query("Sales > 15 & Quantity == 2.0")
        .assign(summary = lambda df_: df_['Sales'] * df_['Quantity'])
        [['Sub-Category', 'Sales']]
        .groupby('Sub-Category').agg(['count', 'mean'])
        .droplevel(axis=1, level=0)
        .query('count > 50')
    )
    return df_good

# %%
df_good1 = pd.DataFrame(dfgood(df))
df_good1
# Out:
#               count        mean
# Sub-Category
# Accessories     157  107.520688
# Appliances       78  133.840000
# Binders         116  234.303138
# Chairs           94  323.293894
# Furnishings      85   68.275482
# Paper            98   64.563469
# Phones          194  235.043773
# Storage         114  165.037298

# %%
# %timeit dfgood(df)
# Out:
# 5.24 ms ± 75.7 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
