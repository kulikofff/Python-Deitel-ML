# %%
from pandas import read_csv, DataFrame
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

dataset = read_csv('newarchiv5iz18092022.csv',',')
dataset.head()
# Out:
#    number  r1  r2  r3  r4  r5
# 0   53236   8  26  24  10  16
# 1   53235   7  34  29  17  35
# 2   53234  17  13  10  11  26
# 3   53233   7  15  32  29  22
# 4   53232  31  15  35  21  36

# %%
dataset.describe()
# Out:
#              number            r1            r2            r3            r4  \
# count  53236.000000  53236.000000  53236.000000  53236.000000  53236.000000
# mean   26618.500000     18.524983     18.494477     18.549760     18.549346
# std    15368.053802     10.427802     10.371718     10.429434     10.372100
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%    13309.750000      9.000000     10.000000     10.000000     10.000000
# 50%    26618.500000     19.000000     18.000000     19.000000     19.000000
# 75%    39927.250000     28.000000     27.000000     28.000000     28.000000
# max    53236.000000     36.000000     36.000000     36.000000     36.000000
#
#                  r5
# count  53236.000000
# mean      18.482756
# std       10.380049
# min        1.000000
# 25%        9.000000
# 50%       18.000000
# 75%       27.000000
# max       36.000000

# %%
trg = dataset[['r1','r2','r3','r4','r5']]
trn = dataset.drop(['r1','r2','r3','r4','r5'], axis=1)

# %%
	models = [LinearRegression(), 
	          RandomForestRegressor(n_estimators=100, max_features ='sqrt'), 
	          KNeighborsRegressor(n_neighbors=6), 
	          ]

# %%
Xtrn, Xtest, Ytrn, Ytest = train_test_split(trn, trg, test_size=0.4)

# %%
print(Xtrn)
# Out:
#        number
# 28092   25144
# 32409   20827
# 52274     962
# 41948   11288
# 50848    2388
# ...       ...
# 13878   39358
# 26280   26956
# 29597   23639
# 44888    8348
# 12211   41025
#
# [31941 rows x 1 columns]

# %%
print(Ytrn)
# Out:
#        r1  r2  r3  r4  r5
# 28092  36  10  11  27   5
# 32409   7   8  18  30  34
# 52274  16  10  12  26   2
# 41948  26  33  13   5  32
# 50848   8  19  27   3  33
# ...    ..  ..  ..  ..  ..
# 13878  29  23   3   6   1
# 26280  13  19   7  31   5
# 29597  21  31  12  15   8
# 44888  30  36  35  34   1
# 12211  27  10  28  30  35
#
# [31941 rows x 5 columns]

# %%
model = models[0]
model.fit(Xtrn, Ytrn)
# X - training data. Y - target values
# Out:
# LinearRegression()

# %%
def user_input_features():
    data = {'number': 53237}
    features = pd.DataFrame(data, index=[0])
    return features
df = user_input_features()
print(df)
# Out:
#    number
# 0   53237

# %%
predictions = model.predict(df)
print(predictions)
# Out:
# [[18.44570831 18.29122193 18.67661619 18.54042911 18.43522637]]

# %%
model1 =models[1]
model1.fit(Xtrn, Ytrn)
# Out:
# RandomForestRegressor(max_features='sqrt', n_estimators=1000)

# %%
predictions = model1.predict(df)
print(predictions)
# Out:
# [[ 8.915 26.621 23.948 11.93  21.374]]

# %%
model2 = models[2]
model2.fit(Xtrn, Ytrn)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
predictions = model2.predict(df)
print(predictions)
# Out:
# [[20.83333333 17.16666667 23.83333333 15.33333333 24.16666667]]
